# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadfakrul/python-Ai-and-image-processing/blob/main/Filtering_Smoothing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import color, data, io
import matplotlib.pyplot as plt

soaps_image = io.imread("/content/soap_image.jpg")

# %%
# Import the filters module and sobel function
from skimage.filters import sobel

# Make the image grayscale
soaps_image_gray = color.rgb2gray(soaps_image)

# Apply edge detection filter
edge_sobel = sobel(soaps_image_gray)

# Show original and resulting image to compare
plt.imshow(soaps_image)
plt.show()
plt.imshow(edge_sobel, cmap="gray")
plt.show()
# show_image(soaps_image, "Edges with Sobel")

# %%
london_image = io.imread("/content/building_image.jpg")

# %%
# Import Gaussian filter
from skimage.filters import gaussian

# Apply filter
gaussian_image = gaussian(london_image, sigma=1)  # Adjust sigma for the desired level of blurring

# Show original and resulting image to compare
plt.imshow(london_image)
plt.show()
plt.imshow(gaussian_image)
plt.show()

# %%
# Import Gaussian filter
from skimage.filters import gaussian

# Apply filter
gaussian_image = gaussian(london_image,sigma=2)

# Show original and resulting image to compare
plt.imshow(london_image)
plt.show()
plt.imshow(gaussian_image)
plt.show()
