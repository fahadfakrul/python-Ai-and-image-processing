# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadfakrul/python-Ai-and-image-processing/blob/main/Contrast_enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import color, data, io
import matplotlib.pyplot as plt

chest_xray_image = io.imread("/content/chest_xray_image.png")
image_aerial = io.imread("/content/image_aerial.tiff")

# %%
# Import the required module
from skimage import exposure

# Show original x-ray image and its histogram
plt.imshow(chest_xray_image, cmap='gray')
plt.show()


plt.title('Histogram of image')
plt.hist(chest_xray_image.ravel(), bins=256)
plt.show()

# %%
# Import the required module
from skimage import exposure

# Show original x-ray image and its histogram
plt.imshow(chest_xray_image, cmap="gray")
plt.show()

plt.title('Histogram of image')
plt.hist(chest_xray_image.ravel(), bins=256)
plt.show()

# Use histogram equalization to improve the contrast
xray_image_eq =  exposure.equalize_hist(chest_xray_image)
plt.imshow(xray_image_eq, cmap="gray")
plt.show()

plt.title('Histogram of image')
plt.hist(xray_image_eq.ravel(), bins=256)
plt.show()

# %%
# Import the required module
from skimage import exposure

# Use histogram equalization to improve the contrast
image_eq =  exposure.equalize_hist(image_aerial)

# Show the original and resulting image
plt.imshow(image_aerial, cmap="gray")
plt.show()
plt.imshow(image_eq, cmap="gray")
plt.show()

# %%
# Import the necessary modules
from skimage import data, exposure
coffee = io.imread("/content/coffee_original.png")
# Load the image
original_image = data.coffee()

# Apply the adaptive equalization on the original image
adapthist_eq_image = exposure.equalize_adapthist(original_image, clip_limit=0.03)

# Compare the original image to the equalized
plt.imshow(original_image, cmap="gray")
plt.show()
plt.imshow(adapthist_eq_image, cmap="gray")
plt.show()
